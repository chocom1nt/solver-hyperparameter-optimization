# %% [markdown]
# # 03. Performance profiles (Dolan–Moré)
#
# Build and plot performance profiles for the runtime metric `wall_time`.

# %%
import pandas as pd
import os, sys

# Ensure `coursework/` is on sys.path when running inside notebooks/.
sys.path.insert(0, os.path.abspath(".."))
import matplotlib.pyplot as plt

from src.analysis.performance_profiles import performance_profile, plot_performance_profile

results_path = "../data/results/exp1.csv"
df = pd.read_csv(results_path)

profile = performance_profile(df, metric="wall_time")
profile.head()

# %%
fig, ax = plt.subplots(figsize=(9, 5))
plot_performance_profile(profile, ax=ax)
plt.show()
